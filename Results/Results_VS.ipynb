# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# pip install openpyxl

# %%
df_FedAvg = pd.read_excel('MODELS_RESULTS.xlsx', sheet_name = 'FedAvg')

# %%
df_FedAvg.fillna(0)
# Out:
#     device                  model  ModelAccuracy       FPR       FNR  \
# 0  laptop1           localtrained       0.988024  0.003401  0.021574
# 1  laptop1  globalmodel_localdata       0.000000  0.000000  1.000000
# 2  laptop2           localtrained       1.000000  0.000000  0.000000
# 3  laptop2  globalmodel_localdata       0.000000  0.000000  1.000000
# 4  laptop3           localtrained       0.666667  0.109375  0.670588
# 5  laptop3  globalmodel_localdata       0.000000  0.000000  1.000000
# 6      all        globalmodel_cum       0.999914  0.000149  0.000000
#
#         TNR       NPV       FDR    Recall  Precision     fbeta        f1  \
# 0  0.996599  0.981027  0.003876  0.978426   0.996124  0.981915  0.987196
# 1  1.000000  0.528144  0.000000  0.000000   0.000000  0.000000  0.000000
# 2  1.000000  1.000000  0.000000  1.000000   1.000000  1.000000  1.000000
# 3  1.000000  0.577754  0.000000  0.000000   0.000000  0.000000  0.000000
# ...

# %%
plt.figure(figsize=(10,6))

# %%
sns.barplot(x='device', y='ModelAccuracy', hue='model', data=df_FedAvg)

plt.title('Comparison of Model Accuracy across Devices Fed Avg')
plt.ylabel('Model Accuracy')
plt.xlabel('Device')
plt.legend(title='Model')

plt.show()

# %%
sns.barplot(x='device', y='FPR', hue='model', data=df_FedAvg)

plt.title('Comparison of FPR across Devices Fed Avg')
plt.ylabel('FPR')
plt.xlabel('Device')
plt.legend(title='Model')

plt.show()

# %%
sns.barplot(x='device', y='FNR', hue='model', data=df_FedAvg)

plt.title('Comparison of FNR across Devices Fed Avg')
plt.ylabel('FNR')
plt.xlabel('Device')
plt.legend(title='Model')

plt.show()

# %%
sns.barplot(x='device', y='TNR', hue='model', data=df_FedAvg)

plt.title('Comparison of TNR across Devices Fed Avg')
plt.ylabel('TNR')
plt.xlabel('Device')
plt.legend(title='Model')

plt.show()

# %%
sns.barplot(x='device', y='NPV', hue='model', data=df_FedAvg)

plt.title('Comparison of NPV across Devices Fed Avg')
plt.ylabel('NPV')
plt.xlabel('Device')
plt.legend(title='Model')

plt.show()

# %%
sns.barplot(x='device', y='FDR', hue='model', data=df_FedAvg)

plt.title('Comparison of NPV across Devices Fed Avg')
plt.ylabel('FDR')
plt.xlabel('Device')
plt.legend(title='Model')

plt.show()

# %%
sns.barplot(x='device', y='Recall', hue='model', data=df_FedAvg)

plt.title('Comparison of RECALL across Devices Fed Avg')
plt.ylabel('Recall')
plt.xlabel('Device')
plt.legend(title='Model')

plt.show()

# %%
sns.barplot(x='device', y='Precision', hue='model', data=df_FedAvg)

plt.title('Comparison of Precision across Devices Fed Avg')
plt.ylabel('Precision')
plt.xlabel('Device')
plt.legend(title='Model')

plt.show()

# %%
sns.barplot(x='device', y='fbeta', hue='model', data=df_FedAvg)

plt.title('Comparison of Fbeta across Devices Fed Avg')
plt.ylabel('fbeta')
plt.xlabel('Device')
plt.legend(title='Model')

plt.show()

# %%
sns.barplot(x='device', y='f1', hue='model', data=df_FedAvg)

plt.title('Comparison of f1 across Devices Fed Avg')
plt.ylabel('f1')
plt.xlabel('Device')
plt.legend(title='Model')

plt.show()

# %%
sns.barplot(x='device', y='f2', hue='model', data=df_FedAvg)

plt.title('Comparison of f2 across Devices Fed Avg')
plt.ylabel('f2')
plt.xlabel('Device')
plt.legend(title='Model')

plt.show()

# %%
sns.barplot(x='device', y='cohen_kappa', hue='model', data=df_FedAvg)

plt.title('Comparison of cohen_kappa across Devices Fed Avg')
plt.ylabel('cohen_kappa')
plt.xlabel('Device')
plt.legend(title='Model')

plt.show()

# %%
sns.barplot(x='device', y='ROC_AUC', hue='model', data=df_FedAvg)

plt.title('Comparison of ROC_AUC across Devices Fed Avg')
plt.ylabel('ROC_AUC')
plt.xlabel('Device')
plt.legend(title='Model')

plt.show()

# %%
sns.barplot(x='device', y='MCC', hue='model', data=df_FedAvg)

plt.title('Comparison of MCC across Devices Fed Avg')
plt.ylabel('MCC')
plt.xlabel('Device')
plt.legend(title='Model')

plt.show()

# %% [markdown]
# # Secure Aggregation

# %%
df_Secure = pd.read_excel('MODELS_RESULTS.xlsx', sheet_name = 'SecureAgg')

df_Secure.fillna(0)
# Out:
#     device                  model  ModelAccuracy       FPR       FNR  \
# 0  laptop1           localtrained       0.996407  0.001134  0.006345
# 1  laptop1  globalmodel_localdata       0.000000  0.000000  1.000000
# 2  laptop2           localtrained       1.000000  0.000000  0.000000
# 3  laptop2  globalmodel_localdata       0.000000  0.000000  0.999983
# 4  laptop3           localtrained       0.713615  0.031250  0.670588
# 5  laptop3  globalmodel_localdata       0.000000  0.000000  1.000000
# 6      all        globalmodel_cum       0.999966  0.000041  0.000026
#
#         TNR       NPV       FDR    Recall  Precision     fbeta        f1  \
# 0  0.998866  0.994357  0.001276  0.993655   0.998724  0.994665  0.996183
# 1  1.000000  0.528144  0.000000  0.000000   0.000000  0.000000  0.000000
# 2  1.000000  1.000000  0.000000  1.000000   1.000000  1.000000  1.000000
# 3  1.000000  0.577758  0.000000  0.000017   1.000000  0.000021  0.000034
# ...

# %%
plt.figure(figsize=(10,6))
sns.barplot(x='device', y='ModelAccuracy', hue='model', data=df_Secure)

plt.title('Comparison of Model Accuracy across Devices Secure Agg')
plt.ylabel('Model Accuracy')
plt.xlabel('Device')
plt.legend(title='Model')

plt.show()

# %%
sns.barplot(x='device', y='FPR', hue='model', data=df_Secure)

plt.title('Comparison of FPR across Devices Secure Agg')
plt.ylabel('FPR')
plt.xlabel('Device')
plt.legend(title='Model')

plt.show()

sns.barplot(x='device', y='FNR', hue='model', data=df_Secure)

plt.title('Comparison of FNR across Devices Secure Agg')
plt.ylabel('FNR')
plt.xlabel('Device')
plt.legend(title='Model')

plt.show()

sns.barplot(x='device', y='TNR', hue='model', data=df_Secure)

plt.title('Comparison of TNR across Devices Secure Agg')
plt.ylabel('TNR')
plt.xlabel('Device')
plt.legend(title='Model')

plt.show()

sns.barplot(x='device', y='NPV', hue='model', data=df_Secure)

plt.title('Comparison of NPV across Devices Secure Agg')
plt.ylabel('NPV')
plt.xlabel('Device')
plt.legend(title='Model')

plt.show()


sns.barplot(x='device', y='FDR', hue='model', data=df_Secure)

plt.title('Comparison of NPV across Devices Secure Agg')
plt.ylabel('FDR')
plt.xlabel('Device')
plt.legend(title='Model')

plt.show()

sns.barplot(x='device', y='Recall', hue='model', data=df_Secure)

plt.title('Comparison of Recall across Devices Secure Agg')
plt.ylabel('Recall')
plt.xlabel('Device')
plt.legend(title='Model')

plt.show()

sns.barplot(x='device', y='Precision', hue='model', data=df_Secure)

plt.title('Comparison of Precision across Devices Secure Agg')
plt.ylabel('Precision')
plt.xlabel('Device')
plt.legend(title='Model')

plt.show()

sns.barplot(x='device', y='fbeta', hue='model', data=df_Secure)

plt.title('Comparison of fbeta across Devices Secure Agg')
plt.ylabel('fbeta')
plt.xlabel('Device')
plt.legend(title='Model')

plt.show()

sns.barplot(x='device', y='f1', hue='model', data=df_Secure)

plt.title('Comparison of f1 across Devices Secure Agg')
plt.ylabel('f1')
plt.xlabel('Device')
plt.legend(title='Model')

plt.show()

sns.barplot(x='device', y='f2', hue='model', data=df_Secure)

plt.title('Comparison of f2 across Devices Secure Agg')
plt.ylabel('f2')
plt.xlabel('Device')
plt.legend(title='Model')

plt.show()

sns.barplot(x='device', y='cohen_kappa', hue='model', data=df_Secure)

plt.title('Comparison of cohen_kappa across Devices Secure Agg')
plt.ylabel('cohen_kappa')
plt.xlabel('Device')
plt.legend(title='Model')

plt.show()

sns.barplot(x='device', y='ROC_AUC', hue='model', data=df_Secure)

plt.title('Comparison of ROC_AUC across Devices Secure Agg')
plt.ylabel('ROC_AUC')
plt.xlabel('Device')
plt.legend(title='Model')

plt.show()

sns.barplot(x='device', y='MCC', hue='model', data=df_Secure)

plt.title('Comparison of MCC across Devices Secure Agg')
plt.ylabel('MCC')
plt.xlabel('Device')
plt.legend(title='Model')

plt.show()

# %% [markdown]
# # Robost

# %%
df_Robost = pd.read_excel('MODELS_RESULTS.xlsx', sheet_name = 'Robost')

df_Robost.fillna(0)

plt.figure(figsize=(10,6))

# %%
sns.barplot(x='device', y='ModelAccuracy', hue='model', data=df_Robost)

plt.title('Comparison of Model Accuracy across Devices Robost')
plt.ylabel('Model Accuracy')
plt.xlabel('Device')
plt.legend(title='Model')

plt.show()

# %%
sns.barplot(x='device', y='FPR', hue='model', data=df_Robost)

plt.title('Comparison of FPR across Devices Robost')
plt.ylabel('FPR')
plt.xlabel('Device')
plt.legend(title='Model')

plt.show()

sns.barplot(x='device', y='FNR', hue='model', data=df_Robost)

plt.title('Comparison of FNR across Devices Robost')
plt.ylabel('FNR')
plt.xlabel('Device')
plt.legend(title='Model')

plt.show()

sns.barplot(x='device', y='TNR', hue='model', data=df_Robost)

plt.title('Comparison of TNR across Devices Robost')
plt.ylabel('TNR')
plt.xlabel('Device')
plt.legend(title='Model')

plt.show()

sns.barplot(x='device', y='NPV', hue='model', data=df_Robost)

plt.title('Comparison of NPV across Devices Robost')
plt.ylabel('NPV')
plt.xlabel('Device')
plt.legend(title='Model')

plt.show()


sns.barplot(x='device', y='FDR', hue='model', data=df_Robost)

plt.title('Comparison of NPV across Devices Robost')
plt.ylabel('FDR')
plt.xlabel('Device')
plt.legend(title='Model')

plt.show()

sns.barplot(x='device', y='Recall', hue='model', data=df_Robost)

plt.title('Comparison of Recall across Devices Robost')
plt.ylabel('Recall')
plt.xlabel('Device')
plt.legend(title='Model')

plt.show()

sns.barplot(x='device', y='Precision', hue='model', data=df_Robost)

plt.title('Comparison of Precision across Devices Robost')
plt.ylabel('Precision')
plt.xlabel('Device')
plt.legend(title='Model')

plt.show()

sns.barplot(x='device', y='fbeta', hue='model', data=df_Robost)

plt.title('Comparison of fbeta across Devices Robost')
plt.ylabel('fbeta')
plt.xlabel('Device')
plt.legend(title='Model')

plt.show()

sns.barplot(x='device', y='f1', hue='model', data=df_Robost)

plt.title('Comparison of f1 across Devices Robost')
plt.ylabel('f1')
plt.xlabel('Device')
plt.legend(title='Model')

plt.show()

sns.barplot(x='device', y='f2', hue='model', data=df_Robost)

plt.title('Comparison of f2 across Devices Robost')
plt.ylabel('f2')
plt.xlabel('Device')
plt.legend(title='Model')

plt.show()

sns.barplot(x='device', y='cohen_kappa', hue='model', data=df_Robost)

plt.title('Comparison of cohen_kappa across Devices Robost')
plt.ylabel('cohen_kappa')
plt.xlabel('Device')
plt.legend(title='Model')

plt.show()

sns.barplot(x='device', y='ROC_AUC', hue='model', data=df_Robost)

plt.title('Comparison of ROC_AUC across Devices Robost')
plt.ylabel('ROC_AUC')
plt.xlabel('Device')
plt.legend(title='Model')

plt.show()

sns.barplot(x='device', y='MCC', hue='model', data=df_Robost)

plt.title('Comparison of MCC across Devices Robost')
plt.ylabel('MCC')
plt.xlabel('Device')
plt.legend(title='Model')

plt.show()
